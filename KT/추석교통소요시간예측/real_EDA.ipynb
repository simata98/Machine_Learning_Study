# %%
import pandas as pd
import math
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings    # 경고메시지 제외
warnings.filterwarnings(action='ignore')

plt.rc('font', family='NanumGothic')
sns.set(font="NanumGothic",
        rc={"axes.unicode_minus":False}, # 마이너스 부호 깨짐 현상 해결
        style='darkgrid')

# %%
df_2017_deageon = pd.read_csv('./data/데이터셋/data_2017_deageon.csv')
df_2017_daegu = pd.read_csv('./data/데이터셋/data_2017_daegu.csv')
df_2017_busan = pd.read_csv('./data/데이터셋/data_2017_busan.csv')
df_2017_gwangju = pd.read_csv('./data/데이터셋/data_2017_gwangju.csv')
df_2017_ganglung = pd.read_csv('./data/데이터셋/data_2017_ganglung.csv')
df_2017_mockpo = pd.read_csv('./data/데이터셋/data_2017_mockpo.csv')

df_2018_deageon = pd.read_csv('./data/데이터셋/data_2018_deageon.csv')
df_2018_daegu = pd.read_csv('./data/데이터셋/data_2018_daegu.csv')
df_2018_busan = pd.read_csv('./data/데이터셋/data_2018_busan.csv')
df_2018_gwangju = pd.read_csv('./data/데이터셋/data_2018_gwangju.csv')
df_2018_ganglung = pd.read_csv('./data/데이터셋/data_2018_ganglung.csv')
df_2018_mockpo = pd.read_csv('./data/데이터셋/data_2018_mockpo.csv')

df_2019_deageon = pd.read_csv('./data/데이터셋/data_2019_deageon.csv')
df_2019_daegu = pd.read_csv('./data/데이터셋/data_2019_daegu.csv')
df_2019_busan = pd.read_csv('./data/데이터셋/data_2019_busan.csv')
df_2019_gwangju = pd.read_csv('./data/데이터셋/data_2019_gwangju.csv')
df_2019_ganglung = pd.read_csv('./data/데이터셋/data_2019_ganglung.csv')
df_2019_mockpo = pd.read_csv('./data/데이터셋/data_2019_mockpo.csv')

df_2020_deageon = pd.read_csv('./data/데이터셋/data_2020_deageon.csv')
df_2020_daegu = pd.read_csv('./data/데이터셋/data_2020_daegu.csv')
df_2020_busan = pd.read_csv('./data/데이터셋/data_2020_busan.csv')
df_2020_gwangju = pd.read_csv('./data/데이터셋/data_2020_gwangju.csv')
df_2020_ganglung = pd.read_csv('./data/데이터셋/data_2020_ganglung.csv')
df_2020_mockpo = pd.read_csv('./data/데이터셋/data_2020_mockpo.csv')

df_2021_deageon = pd.read_csv('./data/데이터셋/data_2021_deageon.csv')
df_2021_daegu = pd.read_csv('./data/데이터셋/data_2021_daegu.csv')
df_2021_busan = pd.read_csv('./data/데이터셋/data_2021_busan.csv')
df_2021_gwangju = pd.read_csv('./data/데이터셋/data_2021_gwangju.csv')
df_2021_ganglung = pd.read_csv('./data/데이터셋/data_2021_ganglung.csv')
df_2021_mockpo = pd.read_csv('./data/데이터셋/data_2021_mockpo.csv')

df_busan = pd.read_csv('./data/데이터셋/data.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_500672/3170152703.py in <module>
# ----> 1 df_2017_deageon = pd.read_csv('./data/데이터셋/data_2017_deageon.csv')
#       2 df_2017_daegu = pd.read_csv('./data/데이터셋/data_2017_daegu.csv')
#       3 df_2017_busan = pd.read_csv('./data/데이터셋/data_2017_busan.csv')
#       4 df_2017_gwangju = pd.read_csv('./data/데이터셋/data_2017_gwangju.csv')
#       5 df_2017_ganglung = pd.read_csv('./data/데이터셋/data_2017_ganglung.csv')
#
# NameError: name 'pd' is not defined

# %%
df_2017_daegu
# Out:
#     when  date  year  hour destination    방향  spend_time
# 0     추석  -3.0  2017     0          대구  귀성방향       201.9
# 1     추석  -3.0  2017     1          대구  귀성방향       189.3
# 2     추석  -3.0  2017     2          대구  귀성방향       183.7
# 3     추석  -3.0  2017     3          대구  귀성방향       176.2
# 4     추석  -3.0  2017     4          대구  귀성방향       174.1
# ..   ...   ...   ...   ...         ...   ...         ...
# 163   추석   3.0  2017    19          대구  귀성방향       179.2
# 164   추석   3.0  2017    20          대구  귀성방향       173.7
# 165   추석   3.0  2017    21          대구  귀성방향       174.9
# 166   추석   3.0  2017    22          대구  귀성방향       177.1
# 167   추석   3.0  2017    23          대구  귀성방향       173.9
#
# [168 rows x 7 columns]

# %%
df_2017_deageon.drop(columns=['Unnamed: 0.1', 'Unnamed: 0'], inplace=True)
df_2017_daegu.drop(columns=['Unnamed: 0.1', 'Unnamed: 0'], inplace=True)
df_2017_busan.drop(columns=['Unnamed: 0.1', 'Unnamed: 0'], inplace=True)
df_2017_gwangju.drop(columns=['Unnamed: 0.1', 'Unnamed: 0'], inplace=True)
df_2017_ganglung.drop(columns=['Unnamed: 0.1', 'Unnamed: 0'], inplace=True)
df_2017_mockpo.drop(columns=['Unnamed: 0.1', 'Unnamed: 0'], inplace=True)

# %%
df_2018_deageon.drop(columns=['Unnamed: 0.1', 'Unnamed: 0'], inplace=True)
df_2018_daegu.drop(columns=['Unnamed: 0.1', 'Unnamed: 0'], inplace=True)
df_2018_busan.drop(columns=['Unnamed: 0.1', 'Unnamed: 0'], inplace=True)
df_2018_gwangju.drop(columns=['Unnamed: 0.1', 'Unnamed: 0'], inplace=True)
df_2018_ganglung.drop(columns=['Unnamed: 0.1', 'Unnamed: 0'], inplace=True)
df_2018_mockpo.drop(columns=['Unnamed: 0.1', 'Unnamed: 0'], inplace=True)

# %%
df_2019_deageon.drop(columns=['Unnamed: 0.1', 'Unnamed: 0'], inplace=True)
df_2019_daegu.drop(columns=['Unnamed: 0.1', 'Unnamed: 0'], inplace=True)
df_2019_busan.drop(columns=['Unnamed: 0.1', 'Unnamed: 0'], inplace=True)
df_2019_gwangju.drop(columns=['Unnamed: 0.1', 'Unnamed: 0'], inplace=True)
df_2019_ganglung.drop(columns=['Unnamed: 0.1', 'Unnamed: 0'], inplace=True)
df_2019_mockpo.drop(columns=['Unnamed: 0.1', 'Unnamed: 0'], inplace=True)

df_2020_deageon.drop(columns=['Unnamed: 0.1', 'Unnamed: 0'], inplace=True)
df_2020_daegu.drop(columns=['Unnamed: 0.1', 'Unnamed: 0'], inplace=True)
df_2020_busan.drop(columns=['Unnamed: 0.1', 'Unnamed: 0'], inplace=True)
df_2020_gwangju.drop(columns=['Unnamed: 0.1', 'Unnamed: 0'], inplace=True)
df_2020_ganglung.drop(columns=['Unnamed: 0.1', 'Unnamed: 0'], inplace=True)
df_2020_mockpo.drop(columns=['Unnamed: 0.1', 'Unnamed: 0'], inplace=True)

df_2021_deageon.drop(columns=['Unnamed: 0.1', 'Unnamed: 0'], inplace=True)
df_2021_daegu.drop(columns=['Unnamed: 0.1', 'Unnamed: 0'], inplace=True)
df_2021_busan.drop(columns=['Unnamed: 0.1', 'Unnamed: 0'], inplace=True)
df_2021_gwangju.drop(columns=['Unnamed: 0.1', 'Unnamed: 0'], inplace=True)
df_2021_ganglung.drop(columns=['Unnamed: 0.1', 'Unnamed: 0'], inplace=True)
df_2021_mockpo.drop(columns=['Unnamed: 0.1', 'Unnamed: 0'], inplace=True)

# %%
df_2017_deageon.to_csv('./data/데이터셋/data_2017_deageon.csv', sep=',', na_rep='NaN', index=False)
df_2017_daegu.to_csv('./data/데이터셋/data_2017_daegu.csv', sep=',', na_rep='NaN', index=False)
df_2017_busan.to_csv('./data/데이터셋/data_2017_busan.csv', sep=',', na_rep='NaN', index=False)
df_2017_gwangju.to_csv('./data/데이터셋/data_2017_gwangju.csv', sep=',', na_rep='NaN', index=False)
df_2017_ganglung.to_csv('./data/데이터셋/data_2017_ganglung.csv', sep=',', na_rep='NaN', index=False)
df_2017_mockpo.to_csv('./data/데이터셋/data_2017_mockpo.csv', sep=',', na_rep='NaN', index=False)

# %%
df_2018_deageon.to_csv('./data/데이터셋/data_2018_deageon.csv', sep=',', na_rep='NaN', index=False)
df_2018_daegu.to_csv('./data/데이터셋/data_2018_daegu.csv', sep=',', na_rep='NaN', index=False)
df_2018_busan.to_csv('./data/데이터셋/data_2018_busan.csv', sep=',', na_rep='NaN', index=False)
df_2018_gwangju.to_csv('./data/데이터셋/data_2018_gwangju.csv', sep=',', na_rep='NaN', index=False)
df_2018_ganglung.to_csv('./data/데이터셋/data_2018_ganglung.csv', sep=',', na_rep='NaN', index=False)
df_2018_mockpo.to_csv('./data/데이터셋/data_2018_mockpo.csv', sep=',', na_rep='NaN', index=False)

df_2019_deageon.to_csv('./data/데이터셋/data_2019_deageon.csv', sep=',', na_rep='NaN', index=False)
df_2019_daegu.to_csv('./data/데이터셋/data_2019_daegu.csv', sep=',', na_rep='NaN', index=False)
df_2019_busan.to_csv('./data/데이터셋/data_2019_busan.csv', sep=',', na_rep='NaN', index=False)
df_2019_gwangju.to_csv('./data/데이터셋/data_2019_gwangju.csv', sep=',', na_rep='NaN', index=False)
df_2019_ganglung.to_csv('./data/데이터셋/data_2019_ganglung.csv', sep=',', na_rep='NaN', index=False)
df_2019_mockpo.to_csv('./data/데이터셋/data_2019_mockpo.csv', sep=',', na_rep='NaN', index=False)

df_2020_deageon.to_csv('./data/데이터셋/data_2020_deageon.csv', sep=',', na_rep='NaN', index=False)
df_2020_daegu.to_csv('./data/데이터셋/data_2020_daegu.csv', sep=',', na_rep='NaN', index=False)
df_2020_busan.to_csv('./data/데이터셋/data_2020_busan.csv', sep=',', na_rep='NaN', index=False)
df_2020_gwangju.to_csv('./data/데이터셋/data_2020_gwangju.csv', sep=',', na_rep='NaN', index=False)
df_2020_ganglung.to_csv('./data/데이터셋/data_2020_ganglung.csv', sep=',', na_rep='NaN', index=False)
df_2020_mockpo.to_csv('./data/데이터셋/data_2020_mockpo.csv', sep=',', na_rep='NaN', index=False)

df_2021_deageon.to_csv('./data/데이터셋/data_2021_deageon.csv', sep=',', na_rep='NaN', index=False)
df_2021_daegu.to_csv('./data/데이터셋/data_2021_daegu.csv', sep=',', na_rep='NaN', index=False)
df_2021_busan.to_csv('./data/데이터셋/data_2021_busan.csv', sep=',', na_rep='NaN', index=False)
df_2021_gwangju.to_csv('./data/데이터셋/data_2021_gwangju.csv', sep=',', na_rep='NaN', index=False)
df_2021_ganglung.to_csv('./data/데이터셋/data_2021_ganglung.csv', sep=',', na_rep='NaN', index=False)
df_2021_mockpo.to_csv('./data/데이터셋/data_2021_mockpo.csv', sep=',', na_rep='NaN', index=False)

# %%
df_2018_deageon.to_csv('./data/데이터셋/data_2018_deageon.csv', sep=',', na_rep='NaN', index=False)
df_2018_daegu.to_csv('./data/데이터셋/data_2018_daegu.csv', sep=',', na_rep='NaN', index=False)
df_2018_busan.to_csv('./data/데이터셋/data_2018_busan.csv', sep=',', na_rep='NaN', index=False)
df_2018_gwangju.to_csv('./data/데이터셋/data_2018_gwangju.csv', sep=',', na_rep='NaN', index=False)
df_2018_ganglung.to_csv('./data/데이터셋/data_2018_ganglung.csv', sep=',', na_rep='NaN', index=False)
df_2018_mockpo.to_csv('./data/데이터셋/data_2018_mockpo.csv', sep=',', na_rep='NaN', index=False)

df_2019_deageon.to_csv('./data/데이터셋/data_2019_deageon.csv', sep=',', na_rep='NaN', index=False)
df_2019_daegu.to_csv('./data/데이터셋/data_2019_daegu.csv', sep=',', na_rep='NaN', index=False)
df_2019_busan.to_csv('./data/데이터셋/data_2019_busan.csv', sep=',', na_rep='NaN', index=False)
df_2019_gwangju.to_csv('./data/데이터셋/data_2019_gwangju.csv', sep=',', na_rep='NaN', index=False)
df_2019_ganglung.to_csv('./data/데이터셋/data_2019_ganglung.csv', sep=',', na_rep='NaN', index=False)
df_2019_mockpo.to_csv('./data/데이터셋/data_2019_mockpo.csv', sep=',', na_rep='NaN', index=False)

df_2020_deageon.to_csv('./data/데이터셋/data_2020_deageon.csv', sep=',', na_rep='NaN', index=False)
df_2020_daegu.to_csv('./data/데이터셋/data_2020_daegu.csv', sep=',', na_rep='NaN', index=False)
df_2020_busan.to_csv('./data/데이터셋/data_2020_busan.csv', sep=',', na_rep='NaN', index=False)
df_2020_gwangju.to_csv('./data/데이터셋/data_2020_gwangju.csv', sep=',', na_rep='NaN', index=False)
df_2020_ganglung.to_csv('./data/데이터셋/data_2020_ganglung.csv', sep=',', na_rep='NaN', index=False)
df_2020_mockpo.to_csv('./data/데이터셋/data_2020_mockpo.csv', sep=',', na_rep='NaN', index=False)

df_2021_deageon.to_csv('./data/데이터셋/data_2021_deageon.csv', sep=',', na_rep='NaN', index=False)
df_2021_daegu.to_csv('./data/데이터셋/data_2021_daegu.csv', sep=',', na_rep='NaN', index=False)
df_2021_busan.to_csv('./data/데이터셋/data_2021_busan.csv', sep=',', na_rep='NaN', index=False)
df_2021_gwangju.to_csv('./data/데이터셋/data_2021_gwangju.csv', sep=',', na_rep='NaN', index=False)
df_2021_ganglung.to_csv('./data/데이터셋/data_2021_ganglung.csv', sep=',', na_rep='NaN', index=False)
df_2021_mockpo.to_csv('./data/데이터셋/data_2021_mockpo.csv', sep=',', na_rep='NaN', index=False)

# %%
df_2017_busan.fillna(0, inplace=True)
df_2017_busan.to_csv('./data/데이터셋/data_2017_busan.csv', sep=',', na_rep='NaN', index=False)

# %%
df_2017_deageon.fillna(0, inplace=True)
df_2017_daegu.fillna(0, inplace=True)
df_2017_busan.fillna(0, inplace=True)
df_2017_gwangju.fillna(0, inplace=True)
df_2017_ganglung.fillna(0, inplace=True)
df_2017_mockpo.fillna(0, inplace=True)

df_2018_deageon.fillna(0, inplace=True)
df_2018_daegu.fillna(0, inplace=True)
df_2018_busan.fillna(0, inplace=True)
df_2018_gwangju.fillna(0, inplace=True)
df_2018_ganglung.fillna(0, inplace=True)
df_2018_mockpo.fillna(0, inplace=True)

df_2019_deageon.fillna(0, inplace=True)
df_2019_daegu.fillna(0, inplace=True)
df_2019_busan.fillna(0, inplace=True)
df_2019_gwangju.fillna(0, inplace=True)
df_2019_ganglung.fillna(0, inplace=True)
df_2019_mockpo.fillna(0, inplace=True)

df_2020_deageon.fillna(0, inplace=True)
df_2020_daegu.fillna(0, inplace=True)
df_2020_busan.fillna(0, inplace=True)
df_2020_gwangju.fillna(0, inplace=True)
df_2020_ganglung.fillna(0, inplace=True)
df_2020_mockpo.fillna(0, inplace=True)

df_2021_deageon.fillna(0, inplace=True)
df_2021_daegu.fillna(0, inplace=True)
df_2021_busan.fillna(0, inplace=True)
df_2021_gwangju.fillna(0, inplace=True)
df_2021_ganglung.fillna(0, inplace=True)
df_2021_mockpo.fillna(0, inplace=True)

# %%
df_2017_deageon.to_csv('./data/데이터셋/data_2017_deageon.csv', sep=',', na_rep='NaN', index=False)
df_2017_daegu.to_csv('./data/데이터셋/data_2017_daegu.csv', sep=',', na_rep='NaN', index=False)
df_2017_busan.to_csv('./data/데이터셋/data_2017_busan.csv', sep=',', na_rep='NaN', index=False)
df_2017_gwangju.to_csv('./data/데이터셋/data_2017_gwangju.csv', sep=',', na_rep='NaN', index=False)
df_2017_ganglung.to_csv('./data/데이터셋/data_2017_ganglung.csv', sep=',', na_rep='NaN', index=False)
df_2017_mockpo.to_csv('./data/데이터셋/data_2017_mockpo.csv', sep=',', na_rep='NaN', index=False)

df_2018_deageon.to_csv('./data/데이터셋/data_2018_deageon.csv', sep=',', na_rep='NaN', index=False)
df_2018_daegu.to_csv('./data/데이터셋/data_2018_daegu.csv', sep=',', na_rep='NaN', index=False)
df_2018_busan.to_csv('./data/데이터셋/data_2018_busan.csv', sep=',', na_rep='NaN', index=False)
df_2018_gwangju.to_csv('./data/데이터셋/data_2018_gwangju.csv', sep=',', na_rep='NaN', index=False)
df_2018_ganglung.to_csv('./data/데이터셋/data_2018_ganglung.csv', sep=',', na_rep='NaN', index=False)
df_2018_mockpo.to_csv('./data/데이터셋/data_2018_mockpo.csv', sep=',', na_rep='NaN', index=False)

df_2019_deageon.to_csv('./data/데이터셋/data_2019_deageon.csv', sep=',', na_rep='NaN', index=False)
df_2019_daegu.to_csv('./data/데이터셋/data_2019_daegu.csv', sep=',', na_rep='NaN', index=False)
df_2019_busan.to_csv('./data/데이터셋/data_2019_busan.csv', sep=',', na_rep='NaN', index=False)
df_2019_gwangju.to_csv('./data/데이터셋/data_2019_gwangju.csv', sep=',', na_rep='NaN', index=False)
df_2019_ganglung.to_csv('./data/데이터셋/data_2019_ganglung.csv', sep=',', na_rep='NaN', index=False)
df_2019_mockpo.to_csv('./data/데이터셋/data_2019_mockpo.csv', sep=',', na_rep='NaN', index=False)

df_2020_deageon.to_csv('./data/데이터셋/data_2020_deageon.csv', sep=',', na_rep='NaN', index=False)
df_2020_daegu.to_csv('./data/데이터셋/data_2020_daegu.csv', sep=',', na_rep='NaN', index=False)
df_2020_busan.to_csv('./data/데이터셋/data_2020_busan.csv', sep=',', na_rep='NaN', index=False)
df_2020_gwangju.to_csv('./data/데이터셋/data_2020_gwangju.csv', sep=',', na_rep='NaN', index=False)
df_2020_ganglung.to_csv('./data/데이터셋/data_2020_ganglung.csv', sep=',', na_rep='NaN', index=False)
df_2020_mockpo.to_csv('./data/데이터셋/data_2020_mockpo.csv', sep=',', na_rep='NaN', index=False)

df_2021_deageon.to_csv('./data/데이터셋/data_2021_deageon.csv', sep=',', na_rep='NaN', index=False)
df_2021_daegu.to_csv('./data/데이터셋/data_2021_daegu.csv', sep=',', na_rep='NaN', index=False)
df_2021_busan.to_csv('./data/데이터셋/data_2021_busan.csv', sep=',', na_rep='NaN', index=False)
df_2021_gwangju.to_csv('./data/데이터셋/data_2021_gwangju.csv', sep=',', na_rep='NaN', index=False)
df_2021_ganglung.to_csv('./data/데이터셋/data_2021_ganglung.csv', sep=',', na_rep='NaN', index=False)
df_2021_mockpo.to_csv('./data/데이터셋/data_2021_mockpo.csv', sep=',', na_rep='NaN', index=False)
