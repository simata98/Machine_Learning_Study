# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
# 데이터 불러오기
train  = pd.read_csv('./data/train.csv')
test  = pd.read_csv('./data/test.csv')

pd.set_option('display.max_columns', None)

# %%
# # 설문조사 항목 결측치 처리
# # 앞 순번 설문조사한 사람의 숫자를 채워넣기로 함
# train = train.fillna(method='ffill')
# test = test.fillna(method='ffill')

# %%
train.drop_duplicates(inplace=True, keep='last')

# %%
# 값이 너무 커서 log 처리
train['intro_log'] = np.log(train['introelapse'])
train['test_log'] = np.log(train['testelapse'])
train['survey_log'] = np.log(train['surveyelapse'])

test['intro_log'] = np.log(test['introelapse'])
test['test_log'] = np.log(test['testelapse'])
test['survey_log'] = np.log(test['surveyelapse'])

# %%
train.drop(['country', 'index'], axis=1, inplace=True)
test.drop(['country', 'index'], axis=1, inplace=True)

# %%
for i,j in train['age'].iteritems():
    if j>100:
        train.loc[i, 'age'] = 100
        
for i,j in test['age'].iteritems():
    if j>100:
        test.loc[i, 'age'] = 100
        
for i,j in train['familysize'].iteritems():
    if j>10:
        train.loc[i, 'familysize'] = 10
        
for i,j in test['familysize'].iteritems():
    if j>10:
        test.loc[i, 'familysize'] = 10

# %%
train.isnull().sum().sum(), test.isnull().sum().sum()
# Out:
# (3513, 7731)

# %%
val_col = train.drop('nerdiness', axis=1).columns

# %%
from sklearn.preprocessing import MinMaxScaler

train[:] = np.nan_to_num(train)
test[:] = np.nan_to_num(test)

scaler = MinMaxScaler()

train[val_col] = scaler.fit_transform(train[val_col])
test[val_col] = scaler.transform(test[val_col])

# %%
from pycaret.classification import *

model = setup(
    data = train,
    target = "nerdiness",
    use_gpu = True,
    train_size=0.90,
    session_id = 2022
)
# Out:
# <style type="text/css">
# #T_47292_row18_col1, #T_47292_row44_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_47292">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_47292_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_47292_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_47292_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_47292_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_47292_row0_col1" class="data row0 col1" >2022</td>
#     </tr>
#     <tr>
#       <th id="T_47292_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_47292_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_47292_row1_col1" class="data row1 col1" >nerdiness</td>
#     </tr>
#     <tr>
#       <th id="T_47292_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_47292_row2_col0" class="data row2 col0" >Target Type</td>
#       <td id="T_47292_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_47292_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_47292_row3_col0" class="data row3 col0" >Label Encoded</td>
#       <td id="T_47292_row3_col1" class="data row3 col1" >0.0: 0, 1.0: 1</td>
#     </tr>
#     <tr>
#       <th id="T_47292_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_47292_row4_col0" class="data row4 col0" >Original Data</td>
#       <td id="T_47292_row4_col1" class="data row4 col1" >(15000, 71)</td>
#     </tr>
#     <tr>
#       <th id="T_47292_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_47292_row5_col0" class="data row5 col0" >Missing Values</td>
#       <td id="T_47292_row5_col1" class="data row5 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_47292_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_47292_row6_col0" class="data row6 col0" >Numeric Features</td>
#       <td id="T_47292_row6_col1" class="data row6 col1" >54</td>
#     </tr>
#     <tr>
#       <th id="T_47292_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_47292_row7_col0" class="data row7 col0" >Categorical Features</td>
#       <td id="T_47292_row7_col1" class="data row7 col1" >16</td>
#     </tr>
#     <tr>
#       <th id="T_47292_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_47292_row8_col0" class="data row8 col0" >Ordinal Features</td>
#       <td id="T_47292_row8_col1" class="data row8 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_47292_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_47292_row9_col0" class="data row9 col0" >High Cardinality Features</td>
#       <td id="T_47292_row9_col1" class="data row9 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_47292_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_47292_row10_col0" class="data row10 col0" >High Cardinality Method</td>
#       <td id="T_47292_row10_col1" class="data row10 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_47292_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_47292_row11_col0" class="data row11 col0" >Transformed Train Set</td>
#       <td id="T_47292_row11_col1" class="data row11 col1" >(13500, 70)</td>
#     </tr>
#     <tr>
#       <th id="T_47292_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_47292_row12_col0" class="data row12 col0" >Transformed Test Set</td>
#       <td id="T_47292_row12_col1" class="data row12 col1" >(1500, 70)</td>
#     </tr>
#     <tr>
#       <th id="T_47292_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_47292_row13_col0" class="data row13 col0" >Shuffle Train-Test</td>
#       <td id="T_47292_row13_col1" class="data row13 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_47292_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_47292_row14_col0" class="data row14 col0" >Stratify Train-Test</td>
#       <td id="T_47292_row14_col1" class="data row14 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_47292_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_47292_row15_col0" class="data row15 col0" >Fold Generator</td>
#       <td id="T_47292_row15_col1" class="data row15 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_47292_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_47292_row16_col0" class="data row16 col0" >Fold Number</td>
#       <td id="T_47292_row16_col1" class="data row16 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_47292_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_47292_row17_col0" class="data row17 col0" >CPU Jobs</td>
#       <td id="T_47292_row17_col1" class="data row17 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_47292_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_47292_row18_col0" class="data row18 col0" >Use GPU</td>
#       <td id="T_47292_row18_col1" class="data row18 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_47292_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_47292_row19_col0" class="data row19 col0" >Log Experiment</td>
#       <td id="T_47292_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_47292_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_47292_row20_col0" class="data row20 col0" >Experiment Name</td>
#       <td id="T_47292_row20_col1" class="data row20 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_47292_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_47292_row21_col0" class="data row21 col0" >USI</td>
#       <td id="T_47292_row21_col1" class="data row21 col1" >6ec7</td>
#     </tr>
#     <tr>
#       <th id="T_47292_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_47292_row22_col0" class="data row22 col0" >Imputation Type</td>
#       <td id="T_47292_row22_col1" class="data row22 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_47292_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_47292_row23_col0" class="data row23 col0" >Iterative Imputation Iteration</td>
#       <td id="T_47292_row23_col1" class="data row23 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_47292_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_47292_row24_col0" class="data row24 col0" >Numeric Imputer</td>
#       <td id="T_47292_row24_col1" class="data row24 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_47292_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_47292_row25_col0" class="data row25 col0" >Iterative Imputation Numeric Model</td>
#       <td id="T_47292_row25_col1" class="data row25 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_47292_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_47292_row26_col0" class="data row26 col0" >Categorical Imputer</td>
#       <td id="T_47292_row26_col1" class="data row26 col1" >constant</td>
#     </tr>
#     <tr>
#       <th id="T_47292_level0_row27" class="row_heading level0 row27" >27</th>
#       <td id="T_47292_row27_col0" class="data row27 col0" >Iterative Imputation Categorical Model</td>
#       <td id="T_47292_row27_col1" class="data row27 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_47292_level0_row28" class="row_heading level0 row28" >28</th>
#       <td id="T_47292_row28_col0" class="data row28 col0" >Unknown Categoricals Handling</td>
#       <td id="T_47292_row28_col1" class="data row28 col1" >least_frequent</td>
#     </tr>
#     <tr>
#       <th id="T_47292_level0_row29" class="row_heading level0 row29" >29</th>
#       <td id="T_47292_row29_col0" class="data row29 col0" >Normalize</td>
#       <td id="T_47292_row29_col1" class="data row29 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_47292_level0_row30" class="row_heading level0 row30" >30</th>
#       <td id="T_47292_row30_col0" class="data row30 col0" >Normalize Method</td>

# %%
# val 5%
top_3_model = compare_models(
                sort="AUC",
                n_select=3, 
                exclude=['xgboost'])
# Out:
# <style type="text/css">
# #T_67c6d th {
#   text-align: left;
# }
# #T_67c6d_row0_col0, #T_67c6d_row0_col3, #T_67c6d_row0_col4, #T_67c6d_row1_col0, #T_67c6d_row1_col1, #T_67c6d_row1_col2, #T_67c6d_row1_col3, #T_67c6d_row1_col4, #T_67c6d_row1_col5, #T_67c6d_row1_col6, #T_67c6d_row1_col7, #T_67c6d_row2_col0, #T_67c6d_row2_col1, #T_67c6d_row2_col2, #T_67c6d_row2_col3, #T_67c6d_row2_col4, #T_67c6d_row2_col5, #T_67c6d_row2_col6, #T_67c6d_row2_col7, #T_67c6d_row3_col0, #T_67c6d_row3_col1, #T_67c6d_row3_col2, #T_67c6d_row3_col3, #T_67c6d_row3_col4, #T_67c6d_row3_col5, #T_67c6d_row3_col6, #T_67c6d_row3_col7, #T_67c6d_row4_col0, #T_67c6d_row4_col1, #T_67c6d_row4_col2, #T_67c6d_row4_col3, #T_67c6d_row4_col4, #T_67c6d_row4_col5, #T_67c6d_row4_col6, #T_67c6d_row4_col7, #T_67c6d_row5_col0, #T_67c6d_row5_col1, #T_67c6d_row5_col2, #T_67c6d_row5_col3, #T_67c6d_row5_col4, #T_67c6d_row5_col5, #T_67c6d_row5_col6, #T_67c6d_row5_col7, #T_67c6d_row6_col0, #T_67c6d_row6_col1, #T_67c6d_row6_col2, #T_67c6d_row6_col3, #T_67c6d_row6_col4, #T_67c6d_row6_col5, #T_67c6d_row6_col6, #T_67c6d_row6_col7, #T_67c6d_row7_col0, #T_67c6d_row7_col1, #T_67c6d_row7_col2, #T_67c6d_row7_col3, #T_67c6d_row7_col4, #T_67c6d_row7_col5, #T_67c6d_row7_col6, #T_67c6d_row7_col7, #T_67c6d_row8_col0, #T_67c6d_row8_col1, #T_67c6d_row8_col2, #T_67c6d_row8_col3, #T_67c6d_row8_col4, #T_67c6d_row8_col5, #T_67c6d_row8_col6, #T_67c6d_row8_col7, #T_67c6d_row9_col0, #T_67c6d_row9_col1, #T_67c6d_row9_col2, #T_67c6d_row9_col3, #T_67c6d_row9_col5, #T_67c6d_row9_col6, #T_67c6d_row9_col7, #T_67c6d_row10_col0, #T_67c6d_row10_col1, #T_67c6d_row10_col2, #T_67c6d_row10_col3, #T_67c6d_row10_col4, #T_67c6d_row10_col5, #T_67c6d_row10_col6, #T_67c6d_row10_col7, #T_67c6d_row11_col0, #T_67c6d_row11_col1, #T_67c6d_row11_col2, #T_67c6d_row11_col4, #T_67c6d_row11_col5, #T_67c6d_row11_col6, #T_67c6d_row11_col7, #T_67c6d_row12_col0, #T_67c6d_row12_col1, #T_67c6d_row12_col2, #T_67c6d_row12_col3, #T_67c6d_row12_col4, #T_67c6d_row12_col5, #T_67c6d_row12_col6, #T_67c6d_row12_col7, #T_67c6d_row13_col0, #T_67c6d_row13_col1, #T_67c6d_row13_col2, #T_67c6d_row13_col3, #T_67c6d_row13_col4, #T_67c6d_row13_col5, #T_67c6d_row13_col6, #T_67c6d_row13_col7 {
#   text-align: left;
# }
# #T_67c6d_row0_col1, #T_67c6d_row0_col2, #T_67c6d_row0_col5, #T_67c6d_row0_col6, #T_67c6d_row0_col7, #T_67c6d_row9_col4, #T_67c6d_row11_col3 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_67c6d_row0_col8, #T_67c6d_row1_col8, #T_67c6d_row2_col8, #T_67c6d_row3_col8, #T_67c6d_row4_col8, #T_67c6d_row5_col8, #T_67c6d_row6_col8, #T_67c6d_row7_col8, #T_67c6d_row8_col8, #T_67c6d_row9_col8, #T_67c6d_row10_col8, #T_67c6d_row12_col8, #T_67c6d_row13_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_67c6d_row11_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_67c6d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_67c6d_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_67c6d_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_67c6d_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_67c6d_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_67c6d_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_67c6d_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_67c6d_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_67c6d_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_67c6d_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_67c6d_level0_row0" class="row_heading level0 row0" >et</th>
#       <td id="T_67c6d_row0_col0" class="data row0 col0" >Extra Trees Classifier</td>
#       <td id="T_67c6d_row0_col1" class="data row0 col1" >0.7924</td>
#       <td id="T_67c6d_row0_col2" class="data row0 col2" >0.8849</td>
#       <td id="T_67c6d_row0_col3" class="data row0 col3" >0.8444</td>
#       <td id="T_67c6d_row0_col4" class="data row0 col4" >0.7935</td>
#       <td id="T_67c6d_row0_col5" class="data row0 col5" >0.8181</td>
#       <td id="T_67c6d_row0_col6" class="data row0 col6" >0.5769</td>
#       <td id="T_67c6d_row0_col7" class="data row0 col7" >0.5785</td>
#       <td id="T_67c6d_row0_col8" class="data row0 col8" >0.8350</td>
#     </tr>
#     <tr>
#       <th id="T_67c6d_level0_row1" class="row_heading level0 row1" >rf</th>
#       <td id="T_67c6d_row1_col0" class="data row1 col0" >Random Forest Classifier</td>
#       <td id="T_67c6d_row1_col1" class="data row1 col1" >0.7911</td>
#       <td id="T_67c6d_row1_col2" class="data row1 col2" >0.8794</td>
#       <td id="T_67c6d_row1_col3" class="data row1 col3" >0.8423</td>
#       <td id="T_67c6d_row1_col4" class="data row1 col4" >0.7929</td>
#       <td id="T_67c6d_row1_col5" class="data row1 col5" >0.8168</td>
#       <td id="T_67c6d_row1_col6" class="data row1 col6" >0.5743</td>
#       <td id="T_67c6d_row1_col7" class="data row1 col7" >0.5758</td>
#       <td id="T_67c6d_row1_col8" class="data row1 col8" >0.6620</td>
#     </tr>
#     <tr>
#       <th id="T_67c6d_level0_row2" class="row_heading level0 row2" >lightgbm</th>
#       <td id="T_67c6d_row2_col0" class="data row2 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_67c6d_row2_col1" class="data row2 col1" >0.7532</td>
#       <td id="T_67c6d_row2_col2" class="data row2 col2" >0.8250</td>
#       <td id="T_67c6d_row2_col3" class="data row2 col3" >0.8114</td>
#       <td id="T_67c6d_row2_col4" class="data row2 col4" >0.7591</td>
#       <td id="T_67c6d_row2_col5" class="data row2 col5" >0.7843</td>
#       <td id="T_67c6d_row2_col6" class="data row2 col6" >0.4968</td>
#       <td id="T_67c6d_row2_col7" class="data row2 col7" >0.4984</td>
#       <td id="T_67c6d_row2_col8" class="data row2 col8" >0.4740</td>
#     </tr>
#     <tr>
#       <th id="T_67c6d_level0_row3" class="row_heading level0 row3" >gbc</th>
#       <td id="T_67c6d_row3_col0" class="data row3 col0" >Gradient Boosting Classifier</td>
#       <td id="T_67c6d_row3_col1" class="data row3 col1" >0.7332</td>
#       <td id="T_67c6d_row3_col2" class="data row3 col2" >0.8057</td>
#       <td id="T_67c6d_row3_col3" class="data row3 col3" >0.7965</td>
#       <td id="T_67c6d_row3_col4" class="data row3 col4" >0.7407</td>
#       <td id="T_67c6d_row3_col5" class="data row3 col5" >0.7675</td>
#       <td id="T_67c6d_row3_col6" class="data row3 col6" >0.4554</td>
#       <td id="T_67c6d_row3_col7" class="data row3 col7" >0.4572</td>
#       <td id="T_67c6d_row3_col8" class="data row3 col8" >3.4690</td>
#     </tr>
#     <tr>
#       <th id="T_67c6d_level0_row4" class="row_heading level0 row4" >lr</th>
#       <td id="T_67c6d_row4_col0" class="data row4 col0" >Logistic Regression</td>
#       <td id="T_67c6d_row4_col1" class="data row4 col1" >0.7255</td>
#       <td id="T_67c6d_row4_col2" class="data row4 col2" >0.7946</td>
#       <td id="T_67c6d_row4_col3" class="data row4 col3" >0.7923</td>
#       <td id="T_67c6d_row4_col4" class="data row4 col4" >0.7329</td>
#       <td id="T_67c6d_row4_col5" class="data row4 col5" >0.7613</td>
#       <td id="T_67c6d_row4_col6" class="data row4 col6" >0.4393</td>
#       <td id="T_67c6d_row4_col7" class="data row4 col7" >0.4414</td>
#       <td id="T_67c6d_row4_col8" class="data row4 col8" >0.3510</td>
#     </tr>
#     <tr>
#       <th id="T_67c6d_level0_row5" class="row_heading level0 row5" >lda</th>
#       <td id="T_67c6d_row5_col0" class="data row5 col0" >Linear Discriminant Analysis</td>
#       <td id="T_67c6d_row5_col1" class="data row5 col1" >0.7248</td>
#       <td id="T_67c6d_row5_col2" class="data row5 col2" >0.7942</td>
#       <td id="T_67c6d_row5_col3" class="data row5 col3" >0.8027</td>
#       <td id="T_67c6d_row5_col4" class="data row5 col4" >0.7277</td>
#       <td id="T_67c6d_row5_col5" class="data row5 col5" >0.7633</td>
#       <td id="T_67c6d_row5_col6" class="data row5 col6" >0.4364</td>
#       <td id="T_67c6d_row5_col7" class="data row5 col7" >0.4396</td

# %%
blended = blend_models(estimator_list = top_3_model, fold = 5, method = 'soft')
# Out:
# <style type="text/css">
# #T_fb2c3_row5_col0, #T_fb2c3_row5_col1, #T_fb2c3_row5_col2, #T_fb2c3_row5_col3, #T_fb2c3_row5_col4, #T_fb2c3_row5_col5, #T_fb2c3_row5_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_fb2c3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fb2c3_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_fb2c3_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_fb2c3_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_fb2c3_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_fb2c3_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_fb2c3_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_fb2c3_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fb2c3_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_fb2c3_row0_col0" class="data row0 col0" >0.7881</td>
#       <td id="T_fb2c3_row0_col1" class="data row0 col1" >0.8633</td>
#       <td id="T_fb2c3_row0_col2" class="data row0 col2" >0.8336</td>
#       <td id="T_fb2c3_row0_col3" class="data row0 col3" >0.7931</td>
#       <td id="T_fb2c3_row0_col4" class="data row0 col4" >0.8128</td>
#       <td id="T_fb2c3_row0_col5" class="data row0 col5" >0.5691</td>
#       <td id="T_fb2c3_row0_col6" class="data row0 col6" >0.5701</td>
#     </tr>
#     <tr>
#       <th id="T_fb2c3_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_fb2c3_row1_col0" class="data row1 col0" >0.7748</td>
#       <td id="T_fb2c3_row1_col1" class="data row1 col1" >0.8541</td>
#       <td id="T_fb2c3_row1_col2" class="data row1 col2" >0.8242</td>
#       <td id="T_fb2c3_row1_col3" class="data row1 col3" >0.7802</td>
#       <td id="T_fb2c3_row1_col4" class="data row1 col4" >0.8016</td>
#       <td id="T_fb2c3_row1_col5" class="data row1 col5" >0.5417</td>
#       <td id="T_fb2c3_row1_col6" class="data row1 col6" >0.5428</td>
#     </tr>
#     <tr>
#       <th id="T_fb2c3_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_fb2c3_row2_col0" class="data row2 col0" >0.7967</td>
#       <td id="T_fb2c3_row2_col1" class="data row2 col1" >0.8695</td>
#       <td id="T_fb2c3_row2_col2" class="data row2 col2" >0.8577</td>
#       <td id="T_fb2c3_row2_col3" class="data row2 col3" >0.7913</td>
#       <td id="T_fb2c3_row2_col4" class="data row2 col4" >0.8232</td>
#       <td id="T_fb2c3_row2_col5" class="data row2 col5" >0.5849</td>
#       <td id="T_fb2c3_row2_col6" class="data row2 col6" >0.5875</td>
#     </tr>
#     <tr>
#       <th id="T_fb2c3_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_fb2c3_row3_col0" class="data row3 col0" >0.7707</td>
#       <td id="T_fb2c3_row3_col1" class="data row3 col1" >0.8498</td>
#       <td id="T_fb2c3_row3_col2" class="data row3 col2" >0.8341</td>
#       <td id="T_fb2c3_row3_col3" class="data row3 col3" >0.7695</td>
#       <td id="T_fb2c3_row3_col4" class="data row3 col4" >0.8005</td>
#       <td id="T_fb2c3_row3_col5" class="data row3 col5" >0.5321</td>
#       <td id="T_fb2c3_row3_col6" class="data row3 col6" >0.5345</td>
#     </tr>
#     <tr>
#       <th id="T_fb2c3_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_fb2c3_row4_col0" class="data row4 col0" >0.7696</td>
#       <td id="T_fb2c3_row4_col1" class="data row4 col1" >0.8537</td>
#       <td id="T_fb2c3_row4_col2" class="data row4 col2" >0.8428</td>
#       <td id="T_fb2c3_row4_col3" class="data row4 col3" >0.7638</td>
#       <td id="T_fb2c3_row4_col4" class="data row4 col4" >0.8014</td>
#       <td id="T_fb2c3_row4_col5" class="data row4 col5" >0.5287</td>
#       <td id="T_fb2c3_row4_col6" class="data row4 col6" >0.5324</td>
#     </tr>
#     <tr>
#       <th id="T_fb2c3_level0_row5" class="row_heading level0 row5" >Mean</th>
#       <td id="T_fb2c3_row5_col0" class="data row5 col0" >0.7800</td>
#       <td id="T_fb2c3_row5_col1" class="data row5 col1" >0.8581</td>
#       <td id="T_fb2c3_row5_col2" class="data row5 col2" >0.8385</td>
#       <td id="T_fb2c3_row5_col3" class="data row5 col3" >0.7796</td>
#       <td id="T_fb2c3_row5_col4" class="data row5 col4" >0.8079</td>
#       <td id="T_fb2c3_row5_col5" class="data row5 col5" >0.5513</td>
#       <td id="T_fb2c3_row5_col6" class="data row5 col6" >0.5534</td>
#     </tr>
#     <tr>
#       <th id="T_fb2c3_level0_row6" class="row_heading level0 row6" >Std</th>
#       <td id="T_fb2c3_row6_col0" class="data row6 col0" >0.0106</td>
#       <td id="T_fb2c3_row6_col1" class="data row6 col1" >0.0072</td>
#       <td id="T_fb2c3_row6_col2" class="data row6 col2" >0.0113</td>
#       <td id="T_fb2c3_row6_col3" class="data row6 col3" >0.0116</td>
#       <td id="T_fb2c3_row6_col4" class="data row6 col4" >0.0089</td>
#       <td id="T_fb2c3_row6_col5" class="data row6 col5" >0.0220</td>
#       <td id="T_fb2c3_row6_col6" class="data row6 col6" >0.0217</td>
#     </tr>
#   </tbody>
# </table>

# %%
pred_holdout = predict_model(blended)
# Out:
# <style type="text/css">
# </style>
# <table id="T_cc3bf">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cc3bf_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_cc3bf_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_cc3bf_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_cc3bf_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_cc3bf_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_cc3bf_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_cc3bf_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_cc3bf_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cc3bf_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_cc3bf_row0_col0" class="data row0 col0" >Voting Classifier</td>
#       <td id="T_cc3bf_row0_col1" class="data row0 col1" >0.7833</td>
#       <td id="T_cc3bf_row0_col2" class="data row0 col2" >0.8551</td>
#       <td id="T_cc3bf_row0_col3" class="data row0 col3" >0.8374</td>
#       <td id="T_cc3bf_row0_col4" class="data row0 col4" >0.7938</td>
#       <td id="T_cc3bf_row0_col5" class="data row0 col5" >0.8150</td>
#       <td id="T_cc3bf_row0_col6" class="data row0 col6" >0.5540</td>
#       <td id="T_cc3bf_row0_col7" class="data row0 col7" >0.5552</td>
#     </tr>
#   </tbody>
# </table>

# %%
final_model = finalize_model(blended)

# %%
predictions = predict_model(final_model, data = test)

# %%
submission = pd.read_csv('./data/sample_submission.csv')

# %%
submission['nerdiness'] = predictions['Label']

# %%
submission.to_csv('전처리두번째.csv', index=False)
