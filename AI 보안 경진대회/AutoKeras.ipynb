# %%
# %pip install autokeras

# %%
import pandas as pd
import numpy as np
import requests
import xgboost
from urllib import parse
from matplotlib import pyplot as plt
import seaborn as sns
from wordcloud import WordCloud
import string

import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, Conv1D, GlobalMaxPooling1D, Dense, Dropout
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import classification_report, accuracy_score
from keras.models import Sequential
from keras.layers import LSTM, Dense, Embedding

from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer

import autokeras as ak
# Out:
# Using TensorFlow backend

# %%
data = pd.read_csv('학습셋_A트랙/A Track 학습셋.csv')
data['decoded_payload'] = data['payload'].apply(lambda x: parse.unquote(x))

max_length = max(len(payload) for payload in data['decoded_payload'])
total_length = sum(len(payload) for payload in data['decoded_payload'])
average_length = total_length / len(data['decoded_payload'])

# %%
X_train, X_test, y_train, y_test = train_test_split(data['decoded_payload'], data['label_action'], stratify = data['label_action'], 
                                                    test_size=0.2, random_state=42)

label_encoder = LabelEncoder()
y_train_encoded = label_encoder.fit_transform(y_train)
y_test_encoded = label_encoder.transform(y_test)


vectorizer = TfidfVectorizer(min_df=0.01, max_df=0.3, analyzer='char', sublinear_tf=True, ngram_range=(1,3), max_features=max_length)
X_train_transformed = vectorizer.fit_transform(X_train)
X_test_transformed = vectorizer.transform(X_test)

# 분할된 데이터프레임의 인덱스를 초기화합니다.
X_train = X_train.reset_index(drop=True)
X_test = X_test.reset_index(drop=True)
y_train = y_train.reset_index(drop=True)
y_test = y_test.reset_index(drop=True)

print(X_train_transformed.shape, X_test_transformed.shape)

# X_train_transformed을 DataFrame으로 변환
X_train_df = pd.DataFrame(X_train_transformed.toarray())

# X_test_transformed을 DataFrame으로 변환
X_test_df = pd.DataFrame(X_test_transformed.toarray())
# Out:
# (36000, 3486) (9000, 3486)

# %%
clf = ak.StructuredDataClassifier(overwrite=True, max_trials=3)
clf.fit(X_train_df, y_train, epochs=10)
predicted_y = clf.predict(X_test_df)
# Out:
# 2023-10-18 16:12:40.809563: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# WARNING:absl:There is a known slowdown when using v2.11+ Keras optimizers on M1/M2 Macs. Falling back to the legacy Keras optimizer, i.e., `tf.keras.optimizers.legacy.Adam`.
# Search: Running Trial #1
#
# Value             |Best Value So Far |Hyperparameter
# True              |True              |structured_data_block_1/normalize
# 2                 |2                 |structured_data_block_1/dense_block_1/num_layers
# False             |False             |structured_data_block_1/dense_block_1/use_batchnorm
# 0                 |0                 |structured_data_block_1/dense_block_1/dropout
# 32                |32                |structured_data_block_1/dense_block_1/units_0
# 32                |32                |structured_data_block_1/dense_block_1/units_1
# 0                 |0                 |classification_head_1/dropout
# adam              |adam              |optimizer
# 0.001             |0.001             |learning_rate
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# WARNING:absl:There is a known slowdown when using v2.11+ Keras optimizers on M1/M2 Macs. Falling back to the legacy Keras optimizer, i.e., `tf.keras.optimizers.legacy.Adam`.
# 2023-10-18 16:12:55.914139: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-10-18 16:12:56.986840: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-10-18 16:12:57.943277: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-10-18 16:12:58.913377: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-10-18 16:12:59.861822: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-10-18 16:13:00.799464: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-10-18 16:13:01.765017: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-10-18 16:13:02.690643: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-10-18 16:13:03.630470: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-10-18 16:13:04.704133: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-10-18 16:13:05.649097: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-10-18 16:13:06.599962: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-10-18 16:13:07.566284: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-10-18 16:13:08.496802: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-10-18 16:13:09.430418: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-10-18 16:13:10.338984: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-10-18 16:13:11.282418: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-10-18 16:13:12.202817: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-10-18 16:13:13.258005: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-10-18 16:13:14.202652: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-10-18 16:13:15.145039: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-10-18 16:13:16.061606: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-10-18 16:13:17.095124: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-10-18 16:13:18.220050: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-10-18 16:13:19.421476: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-10-18 16:13:20.341101: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-10-18 16:13:21.258292: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-10-18 16:13:22.137928: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-10-18 16:13:23.011498: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-10-18 16:13:24.214938: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-10-18 16:13:25.106441: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-10-18 16:13:25.986301: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-10-18 16:13:26.869857: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-10-18 16:13:27.847343: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-10-18 16:13:28.901480: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-10-18 16:13:29.938557: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-10-18 16:13:31.049083: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-10-18 16:13:32.147634: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-10-18 16:13:33.165908: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-10-18 16:13:34.210549: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-10-18 16:13:35.080533: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-10-18 16:13:36.033590: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-10-18 16:13:36.940440: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-10-18 16:13:37.883666: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-10-18 16:13:38.779961: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-10-18 16:13:39.695480: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-10-18 16:13:40.562152: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-10-18 16:13:41.425651: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-10-18 16:13:42.419875: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-10-18 16:13:43.524875: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-10-18 16:13:44.514522: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-10-18 16:13:45.832366: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-10-18 16:13:47.111104: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-10-18 16:13:48.065915: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-10-18 16:13:49.033495: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-10-18 16:13:50.070910: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-10-18 16:13:51.170719: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-10-18 16:13:52.071915: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-10-18 16:13:52.969042: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-10-18 16:13:53.933653: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-10-18 16:13:54.854660: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-10-18 16:13:55.879245: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-10-18 16:13:56.850732: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-10-18 16:13:57.837248: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-10-18 16:13:58.702493: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-10-18 16:13:59.703437: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-10-18 16:14:00.688569: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-10-18 16:14:01.675000: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-10-18 16:14:02.651110: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-10-18 16:14:03.527669: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-10-18 16:14:04.599761: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-10-18 16:14:05.675934: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-10-18 16:14:06.573970: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-10-18 16:14:07.546806: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-10-18 16:14:08.623778: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-10-18 16:14:09.565690: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-10-18 16:14:10.511856: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-10-18 16:14:11.424416: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-10-18 16:14:12.341864: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-10-18 16:14:13.333084: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-10-18 16:14:14.377920: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-10-18 16:14:15.252011: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-10-18 16:14:16.134202: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-10-18 16:14:17.003873: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-10-18 16:14:17.961518: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-10-18 16:14:18.831550: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-10-18 16:14:19.705656: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-10-18 16:14:20.568675: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-10-18 16:14:21.434565: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-10-18 16:14:22.301322: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-10-18 16:14:23.165753: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-10-18 16:14:24.030135: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-10-18 16:14:24.933082: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-10-18 16:14:25.855961: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-10-18 16:14
I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-10-18 16:18:04.929541: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-10-18 16:18:05.850957: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-10-18 16:18:06.793720: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-10-18 16:18:07.772344: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-10-18 16:18:08.692862: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/c4nd0it/workspace/대회/2023_AI_Sec/AutoKeras.ipynb 셀 5 line 2
#       <a href='vscode-notebook-cell:/Users/c4nd0it/workspace/%EB%8C%80%ED%9A%8C/2023_AI_Sec/AutoKeras.ipynb#W4sZmlsZQ%3D%3D?line=0'>1</a> clf = ak.StructuredDataClassifier(overwrite=True, max_trials=3)
# ----> <a href='vscode-notebook-cell:/Users/c4nd0it/workspace/%EB%8C%80%ED%9A%8C/2023_AI_Sec/AutoKeras.ipynb#W4sZmlsZQ%3D%3D?line=1'>2</a> clf.fit(X_train_df, y_train, epochs=10)
#       <a href='vscode-notebook-cell:/Users/c4nd0it/workspace/%EB%8C%80%ED%9A%8C/2023_AI_Sec/AutoKeras.ipynb#W4sZmlsZQ%3D%3D?line=2'>3</a> predicted_y = clf.predict(X_test_df)
#
# File /opt/miniconda3/envs/tf_env/lib/python3.8/site-packages/autokeras/tasks/structured_data.py:326, in StructuredDataClassifier.fit(self, x, y, epochs, callbacks, validation_split, validation_data, **kwargs)
#     279 def fit(
#     280     self,
#     281     x=None,
#    (...)
#     287     **kwargs
#     288 ):
#     289     """Search for the best model and hyperparameters for the AutoModel.
#     290
#     291     # Arguments
#    (...)
#     324             validation loss values and validation metrics values (if applicable).
#     325     """
# --> 326     history = super().fit(
#     327         x=x,
#     328         y=y,
#     329         epochs=epochs,
#     330         callbacks=callbacks,
#     331         validation_split=validation_split,
#     332         validation_data=validation_data,
#     333         **kwargs
#     334     )
#     335     return history
#
# File /opt/miniconda3/envs/tf_env/lib/python3.8/site-packages/autokeras/tasks/structured_data.py:139, in BaseStructuredDataPipeline.fit(self, x, y, epochs, callbacks, validation_split, validation_data, **kwargs)
#     135         validation_data = self._read_from_csv(x_val, y_val)
#     137 self.check_in_fit(x)
# --> 139 history = super().fit(
#     140     x=x,
#     141     y=y,
#     142     epochs=epochs,
#     143     callbacks=callbacks,
#     144     validation_split=validation_split,
#     145     validation_data=validation_data,
#     146     **kwargs
#     147 )
#     148 return history
#
# File /opt/miniconda3/envs/tf_env/lib/python3.8/site-packages/autokeras/auto_model.py:292, in AutoModel.fit(self, x, y, batch_size, epochs, callbacks, validation_split, validation_data, verbose, **kwargs)
#     287 if validation_data is None and validation_split:
#     288     dataset, validation_data = data_utils.split_dataset(
#     289         dataset, validation_split
#     290     )
# --> 292 history = self.tuner.search(
#     293     x=dataset,
#     294     epochs=epochs,
#     295     callbacks=callbacks,
#     296     validation_data=validation_data,
#     297     validation_split=validation_split,
#     298     verbose=verbose,
#     299     **kwargs
#     300 )
#     302 return history
#
# File /opt/miniconda3/envs/tf_env/lib/python3.8/site-packages/autokeras/engine/tuner.py:193, in AutoTuner.search(self, epochs, callbacks, validation_split, verbose, **fit_kwargs)
#     191 self._try_build(hp)
#     192 self.oracle.update_space(hp)
# --> 193 super().search(
#     194     epochs=epochs, callbacks=new_callbacks, verbose=verbose, **fit_kwargs
#     195 )
#     197 # Train the best model use validation data.
#     198 # Train the best model with enough number of epochs.
#     199 if validation_split > 0 or early_stopping_inserted:
#
# File /opt/miniconda3/envs/tf_env/lib/python3.8/site-packages/keras_tuner/src/engine/base_tuner.py:233, in BaseTuner.search(self, *fit_args, **fit_kwargs)
#     230         continue
#     232     self.on_trial_begin(trial)
# --> 233     self._try_run_and_update_trial(trial, *fit_args, **fit_kwargs)
#     234     self.on_trial_end(trial)
#     235 self.on_search_end()
#
# File /opt/miniconda3/envs/tf_env/lib/python3.8/site-packages/keras_tuner/src/engine/base_tuner.py:273, in BaseTuner._try_run_and_update_trial(self, trial, *fit_args, **fit_kwargs)
#     271 def _try_run_and_update_trial(self, trial, *fit_args, **fit_kwargs):
#     272     try:
# --> 273         self._run_and_update_trial(trial, *fit_args, **fit_kwargs)
#     274         trial.status = trial_module.TrialStatus.COMPLETED
#     275         return
#
# File /opt/miniconda3/envs/tf_env/lib/python3.8/site-packages/keras_tuner/src/engine/base_tuner.py:238, in BaseTuner._run_and_update_trial(self, trial, *fit_args, **fit_kwargs)
#     237 def _run_and_update_trial(self, trial, *fit_args, **fit_kwargs):
# --> 238     results = self.run_trial(trial, *fit_args, **fit_kwargs)
#     239     if self.oracle.get_trial(trial.trial_id).metrics.exists(
#     240         self.oracle.objective.name
#     241     ):
#     242         # The oracle is updated by calling `self.oracle.update_trial()` in
#     243         # `Tuner.run_trial()`. For backward compatibility, we support this
#     244         # use case. No further action needed in this case.
#     245         warnings.warn(
#     246             "The use case of calling "
#     247             "`self.oracle.update_trial(trial_id, metrics)` "
#    (...)
#     253             stacklevel=2,
#     254         )
#
# File /opt/miniconda3/envs/tf_env/lib/python3.8/site-packages/keras_tuner/src/engine/tuner.py:314, in Tuner.run_trial(self, trial, *args, **kwargs)
#     312     callbacks.append(model_checkpoint)
#     313     copied_kwargs["callbacks"] = callbacks
# --> 314     obj_value = self._build_and_fit_model(trial, *args, **copied_kwargs)
#     316     histories.append(obj_value)
#     317 return histories
#
# File /opt/miniconda3/envs/tf_env/lib/python3.8/site-packages/autokeras/engine/tuner.py:99, in AutoTuner._build_and_fit_model(self, trial, *args, **kwargs)
#      92 (
#      93     pipeline,
#      94     kwargs["x"],
#      95     kwargs["validation_data"],
#      96 ) = self._prepare_model_build(trial.hyperparameters, **kwargs)
#      97 pipeline.save(self._pipeline_path(trial.trial_id))
# ---> 99 self.adapt(model, kwargs["x"])
#     101 _, history = utils.fit_with_adaptive_batch_size(
#     102     model, self.hypermodel.batch_size, **kwargs
#     103 )
#     104 return history
#
# File /opt/miniconda3/envs/tf_env/lib/python3.8/site-packages/autokeras/engine/tuner.py:136, in AutoTuner.adapt(model, dataset)
#     134 while len(dq):
#     135     layer, in_x = dq.popleft()
# --> 136     layer.adapt(in_x)
#     137     out_x = in_x.map(layer)
#     138     for next_layer in get_output_layers(layer.output):
#
# File /opt/miniconda3/envs/tf_env/lib/python3.8/site-packages/autokeras/keras_layers.py:114, in MultiCategoryEncoding.adapt(self, data)
#     112     continue
#     113 data_column = data.map(lambda x: tf.slice(x, [0, index], [-1, 1]))
# --> 114 encoding_layer.adapt(data_column.map(data_utils.cast_to_string))
#
# File /opt/miniconda3/envs/tf_env/lib/python3.8/site-packages/keras/src/layers/preprocessing/string_lookup.py:410, in StringLookup.adapt(self, data, batch_size, steps)
#     360 def adapt(self, data, batch_size=None, steps=None):
#     361     """Computes a vocabulary of string terms from tokens in a dataset.
#     362
#     363     Calling `adapt()` on a `StringLookup` layer is an alternative to passing
#    (...)
#     408           argument is not supported with array inputs.
#     409     """
# --> 410     super().adapt(data, batch_size=batch_size, steps=steps)
#
# File /opt/miniconda3/envs/tf_env/lib/python3.8/site-packages/keras/src/engine/base_preprocessing_layer.py:255, in PreprocessingLayer.adapt(self, data, batch_size, steps)
#     246 data_handler = data_adapter.DataHandler(
#     247     data,
#     248     batch_size=batch_size,
#    (...)
#     252     distribute=False,
#     253 )
#     254 self._adapt_function = self.make_adapt_function()
# --> 255 for _, iterator in data_handler.enumerate_epochs():
#     256     with data_handler.catch_stop_iteration():
#     257         for _ in data_handler.steps():
#
# File /opt/miniconda3/envs/tf_env/lib/python3.8/site-packages/keras/src/engine/data_adapter.py:1331, in DataHandler.enumerate_epochs(self)
#    1329 """Yields `(epoch, tf.data.Iterator)`."""
#    1330 with self._truncate_execution_to_epoch():
# -> 1331     data_iterator = iter(self._dataset)
#    1332     for epoch in range(self._initial_epoch, self._epochs):
#    1333         if self._insufficient_data:  # Set by `catch_stop_iteration`.
#
# File /opt/miniconda3/envs/tf_env/lib/python3.8/site-packages/tensorflow/python/data/ops/dataset_ops.py:506, in DatasetV2.__iter__(self)
#     504 if context.executing_eagerly() or ops.inside_function():
#     505   with ops.colocate_with(self._variant_tensor):
# --> 506     return iterator_ops.OwnedIterator(self)
#     507 else:
#     508   raise RuntimeError("`tf.data.Dataset` only supports Python-style "
#     509                      "iteration in eager mode or within tf.function.")
#
# File /opt/miniconda3/envs/tf_env/lib/python3.8/site-packages/tensorflow/python/data/ops/iterator_ops.py:710, in OwnedIterator.__init__(self, dataset, components, element_spec)
#     706   if (components is not None or element_spec is not None):
#     707     raise ValueError(
#     708         "When `dataset` is provided, `element_spec` and `components` must "
#     709         "not be specified.")
# --> 710   self._create_iterator(dataset)
#     712 self._get_next_call_count = 0
#
# File /opt/miniconda3/envs/tf_env/lib/python3.8/site-packages/tensorflow/python/data/ops/iterator_ops.py:749, in OwnedIterator._create_iterator(self, dataset)
#     746   assert len(fulltype.args[0].args[0].args) == len(
#     747       self._flat_output_types)
#     748   self._iterator_resource.op.experimental_set_type(fulltype)
# --> 749 gen_dataset_ops.make_iterator(ds_variant, self._iterator_resource)
#
# File /opt/miniconda3/envs/tf_env/lib/python3.8/site-packages/tensorflow/python/ops/gen_dataset_ops.py:3420, in make_iterator(dataset, iterator, name)
#    3418 if tld.is_eager:
#    3419   try:
# -> 3420     _result = pywrap_tfe.TFE_Py_FastPathExecute(
#    3421       _ctx, "MakeIterator", name, dataset, iterator)
#    3422     return _result
#    3423   except _core._NotOkStatusException as e:
#
# KeyboardInterrupt:
